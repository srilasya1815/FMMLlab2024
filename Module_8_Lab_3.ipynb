# %% [markdown]
# <a href="https://colab.research.google.com/github/srilasya1815/FMMLlab2024/blob/main/Module_8_Lab_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Bayesian Machine Learning: Lab 3 - Applying Bayes Classifiers

# %% [markdown]
# Lab by V Vijay Vignesh
#
# vijay.vignesh@research.iiit.ac.in

# %%
import os
import json
import re

import numpy as np
import pandas as pd

from matplotlib import pyplot as plt
import seaborn as sns
import plotly.express as px
import plotly.graph_objects as pg

import tensorflow as tf
import tensorflow_probability as tfp

# %%
# !wget https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
plt.style.use('ggplot')
# Out:
# --2025-03-22 15:48:35--  https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 72422946 (69M) [text/plain]
# Saving to: ‘arxiv-paper-data.json’
#
# arxiv-paper-data.js 100%[===================>]  69.07M   119MB/s    in 0.6s
#
# 2025-03-22 15:48:37 (119 MB/s) - ‘arxiv-paper-data.json’ saved [72422946/72422946]

# %% [markdown]
# Let's make a few assumptions to come up with our first general model for classification:
# * The different features contribute equally to the result
# * The features are independent

# %% [markdown]
# ## Bayes Classifiers in Scikit Learn

# %% [markdown]
# ### Simple 1-D Classfication using Naive Bayes in Continuous Space

# %%
fig, ax = plt.subplots(figsize=(18, 8))
x1 = np.random.normal(1.0, 0.3, size=5000)
x2 = np.random.normal(0.0, 0.3, size=50000)
x = np.concatenate([x1, x2])
y = np.concatenate([np.zeros(len(x1)), np.ones(len(x2))])
sns.histplot(x1, color='blue', alpha=0.5, ax=ax)
sns.histplot(x2, color='red', alpha=0.5, ax=ax)
ax.fill_between(np.linspace(-1.0, 0.7, 100), 0, 1800,  color='r', alpha=0.1)
ax.fill_between(np.linspace(0.7, 2.0, 100), 0, 1800,  color='b', alpha=0.1)
ax.vlines(0.5, 0, 1750, color="k", linestyles="--", lw=3)
ax.vlines(0.7, 0, 1750, color="g", linestyles="--", lw=3)
ax.scatter(x1, [np.random.randint(2000, 3000) for _ in x1], color='b', s=1)
ax.scatter(x2, [np.random.randint(2000, 3000) for _ in x2], color='r', s=1)
ax.set_xlim(-1.0, 2.0)
ax.set_ylim(0, 3200)
plt.show()

# %%
from sklearn.naive_bayes import GaussianNB
gnb = GaussianNB()
x_reshaped = x.reshape(1, -1)
print(x_reshaped.shape)
# Out:
# (1, 55000)

# %% [markdown]
# ## Gaussian Bayes Predictor on Predicting Flowers

# %% [markdown]
# ### Predictors in Scikit Learn

# %%
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import GaussianNB

X, y = load_iris(return_X_y=True)
X = X[:, [2, 3]]
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.5, random_state=0)
gnb = GaussianNB()
gnb.fit(X_train, y_train)
# Out:
# GaussianNB()

# %%
plt.figure(figsize=(20, 10))
color_scheme = ['red', 'green', 'blue']
plt.scatter(X_train[:, 0], X_train[:, 1], c=[color_scheme[idx] for idx in y_train])
plt.show()

# %% [markdown]
# ### Visualizing the Decision Surface

# %%
plt.figure(figsize=(20, 10))
X1_scan, X2_scan = np.meshgrid(np.linspace(0.5, 7.5, 250), np.linspace(0.0, 3.0, 250))
X_scan = np.stack([np.reshape(X1_scan, -1), np.reshape(X2_scan, -1)], axis=-1)
predictions = gnb.predict(X_scan)
color_map = ['r', 'g', 'b']
plt.scatter(x=X_test[:, 0], y=X_test[:, 1], c=[color_map[x] for x in y_test])
sns.kdeplot(x=X_scan[:, 0], y=X_scan[:, 1], hue=[color_map[x] for x in predictions], fill=False)
plt.show()

# %% [markdown]
# ## Bayes on Text - Classifying papers at Arxiv

# %% [markdown]
# ### Data Cleaning and Preprocessing

# %%
arxiv_df = pd.read_json(open("arxiv-paper-data.json", 'r'))
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: json.loads(x.replace("\'", "\"").replace("None", "\"None\""))[0]['term'].split('.')[0])
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: 'physics' if x in ['physics', 'quant-ph', 'astro-ph', 'hep-ex', 'hep-ph', 'hep-lat', 'hep-th', 'nucl-th'] else x)
arxiv_df = arxiv_df.drop(["day", "month", "link", "author"], axis=1)

# %%
SAMPLES_COMP = 3500 #@param {type: "slider", min: 1000, max: 4500}
SAMPLES_STAT = 2500 #@param {type: "slider", min: 1000, max: 4500}
WORD_COUNT_THRESHOLD = 1  #@param {type: "slider", min: 1, max: 500}
WORD_LENGTH_THRESHOLD = 8  #@param {type: "slider", min: 4, max: 20}

# %%
df = pd.concat([arxiv_df[arxiv_df['tag'] == 'cs'].sample(SAMPLES_COMP, replace=False),
                arxiv_df[arxiv_df['tag'] == 'stat'].sample(SAMPLES_STAT, replace=False)]).sample(frac=1)
df['keywords'] = df.apply(lambda x: [word.lower() for word in re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', x.summary + ' ' + x.title)).split()
                                     if len(word) > WORD_LENGTH_THRESHOLD and not re.search('(\d|\(|\))', word)], axis=1)
train_df, test_df = df.iloc[:int(len(df) * 0.8)], df.iloc[int(len(df) * 0.8):]

train_df
# Out:
#                  id                                            summary   tag  \
# 22613  1702.08320v2  The pseudo-likelihood method is one of the mos...  stat
# 10494   1406.7842v3  The construction of a meaningful graph plays a...    cs
# 12075  1707.05807v1  The pairwise influence matrix of Dobrushin has...  stat
# 32891  1510.06002v2  We present an efficient method for training sl...    cs
# 7065   1709.07625v1  Regularized empirical risk minimization using ...  stat
# ...             ...                                                ...   ...
# 39647  1611.05963v4  The t-SVD based Tensor Robust Principal Compon...    cs
# 35505   0805.0785v2  If a computer node is infected by a virus, wor...    cs
# 22940  1711.05150v1  Network clustering reveals the organization of...  stat
# 1002   1507.00210v1  We introduce Natural Neural Networks, a novel ...  stat
# 1740   1504.01255v3  This paper presents a new semi-supervised fram...  stat
#
#                                                    title  year  \
# 22613  An Efficient Pseudo-likelihood Method for Spar...  2017
# 10494  Learning Laplacian Matrix in Smooth Graph Sign...  2014
# 12075     Improving Gibbs Sampler Scan Quality with DoGS  2017
# 32891  Fast and Scalable Structural SVM with Slack Re...  2015
# 7065                   Total stability of kernel methods  2017
# ...                                                  ...   ...
# 39647  Reweighted Low-Rank Tensor Decomposition based...  2016
# 35505  AGNOSCO - Identification of Infected Nodes wit...  2008
# 22940  Fast and reliable inference algorithm for hier...  2017
# 1002                             Natural Neural Networks  2015
# 1740   Semi-supervised Convolutional Neural Networks ...  2015
#
#                                                 keywords
# 22613  [likelihood, algorithms, formulate, regularize...
# 10494  [construction, meaningful, representations, al...
# 12075  [influence, dobrushin, analytical, convergence...
# 32891  [efficient, structural, violating, formulation...
# 7065   [regularized, empirical, minimization, corresp...
# ...                                                  ...
# 39647  [principal, component, decomposes, corrupted, ...
# 35505  [structure, associated, intrusion, detection, ...
# 22940  [clustering, organization, corresponding, repr...
# 1002   [introduce, algorithms, convergence, represent...
# 1740   [supervised, framework, convolutional, categor...
#
# [4800 rows x 6 columns]

# %%
df['keywords']
# Out:
# 22613    [likelihood, algorithms, formulate, regularize...
# 10494    [construction, meaningful, representations, al...
# 12075    [influence, dobrushin, analytical, convergence...
# 32891    [efficient, structural, violating, formulation...
# 7065     [regularized, empirical, minimization, corresp...
#                                ...
# 11897    [consequences, decisions, insurance, predictiv...
# 5947     [generative, dirichlet, characterizing, sequen...
# 22107    [considers, classification, variables, observa...
# 7511     [functions, univariate, multivariate, generati...
# 2191     [approaches, abstraction, capturing, regularit...
# Name: keywords, Length: 6000, dtype: object

# %% [markdown]
# ### Learning Probability Distributions

# %%
from collections import defaultdict
dictionary = defaultdict(lambda: [0, 0])
for desc, tag in zip(df['keywords'], df['tag']):
    for word in set(desc):
        if tag == 'cs':
            dictionary[word][0] += 1
        else:
            dictionary[word][1] += 1

print("We have a dictionary of", len(dictionary), "words.")

words, counts_cs, counts_stat = [], [], []
for word, count in dictionary.items():
    if count[0] + count[1] > WORD_COUNT_THRESHOLD:
        words.append(word)
        counts_cs.append(count[0])
        counts_stat.append(count[1])
print("Out of those", len(words), f"have over {WORD_COUNT_THRESHOLD} occurances")

fig = pg.Figure([pg.Bar(x=words[:200], y=counts_cs[:200]),
                 pg.Bar(x=words[:200], y=counts_stat[:200])])
fig.update_layout(title_text=f'Some random words and the frequency plot of those with over {WORD_COUNT_THRESHOLD} occurances')
fig.show()
# Out:
# We have a dictionary of 8737 words.
# Out of those 4548 have over 1 occurances
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="dab01091-2c4c-49dc-87ac-f63fef753c4d" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("dab01091-2c4c-49dc-87ac-f63fef753c4d")) {                    Plotly.newPlot(                        "dab01091-2c4c-49dc-87ac-f63fef753c4d",                        [{"x":["dimensional","experiments","demonstrate","estimation","therefore","numerical","specifically","regularization","parameters","regression","coordinate","penalties","substantial","screening","procedures","efficient","simulated","generalized","formulate","furthermore","regularized","algorithms","unbalanced","algorithm","likelihood","penalized","optimization","advantages","available","desirable","representation","meaningful","depending","smoothness","processing","minimizing","observations","laplacian","synthetic","structured","efficiently","probabilistic","laplacians","framework","application","construction","equivalent","particular","regularity","variations","topologies","applications","variables","representations","especially","resulting","selection","certifiable","recognition","significantly","practical","improving","systematic","improvements","influence","customized","consistently","optimized","variation","analytical","inferences","stationarity","inference","segmentation","convergence","decomposes","approaches","violating","magnitude","structure","difficult","formulation","contribution","structural","rescaling","conditions","dependent","parameter","important","complicated","hierarchical","estimated","approximation","stability","classical","perturbations","minimization","considered","probability","corresponding","hyperparameters","simultaneous","statistics","iterative","lipschitz","empirical","reproducing","extracted","necessary","classification","knowledge","automatically","comparable","conditional","perception","perceptron","techniques","production","architectures","extraction","estimating","performance","different","conventional","extracting","probabilities","motivated","multilayer","separating","convolutional","automatic","indicates","estimates","investigates","comprehensive","satisfies","clarifies","correctly","hopefully","precision","principles","presented","propositional","monotonic","quantified","reasoning","situations","plausible","traditional","evaluating","differences","optimizer","continuous","inspecting","interpreting","inherently","legislative","improvement","political","approximate","correlated","prediction","exploratory","providing","variational","posterior","including","implemented","characteristics","exhibiting","extensions","sensitivity","asymmetric","compression","represents","reproduce","implementation","neuromorphic","frequency","electronic","filtering","implementations","described","implement","nonlinear","discrimination","separates","transmitted","remarkable","decomposition","polygonal","triggered","likelihoods","perturbative","statistical","covariances","importance","gradients","enumerated","perturbation"],"y":[180,590,555,189,149,80,166,80,241,93,17,6,40,10,30,418,59,62,56,156,51,613,4,779,65,6,298,95,305,31,356,66,40,19,291,54,70,20,131,98,166,163,2,553,238,64,45,311,9,70,4,408,120,197,118,149,165,0,364,235,130,112,44,111,58,8,32,48,61,17,10,6,219,203,127,13,433,3,58,355,144,93,80,73,4,128,71,130,352,35,103,71,122,34,80,23,62,137,183,146,11,38,70,77,7,157,5,102,54,519,320,174,88,105,40,19,380,12,119,140,68,895,740,106,57,59,61,14,11,373,191,24,81,24,57,14,1,38,3,72,37,176,32,12,13,128,56,25,174,61,46,5,103,1,8,20,2,146,10,101,26,216,5,78,52,64,256,115,91,8,47,41,9,49,53,9,122,13,61,24,64,46,87,68,61,9,8,3,22,75,5,6,5,1,176,3,90,30,1,13],"type":"bar"},{"x":["dimensional","experiments","demonstrate","estimation","therefore","numerical","specific ...

# %% [markdown]
# For each word, for both the subjects, we can apply Bayes rule.
#
# $$P\bigg(\frac{\text{subject}}{\text{word}}\bigg) = P\bigg(\frac{\text{word}}{\text{subject}}\bigg) \times \frac{P(\text{subject})}{P(\text{word})}$$

# %% [markdown]
# ### Computing the resultant probabilities

# %%
prior = np.array([train_df["tag"].value_counts()["cs"], train_df["tag"].value_counts()["stat"]]) / len(train_df)
evidence = np.array([counts_cs / train_df["tag"].value_counts()["cs"], counts_stat / train_df["tag"].value_counts()["stat"]]).T
likelihood = (np.array(counts_cs) + np.array(counts_stat)) / len(train_df)

prior.shape, likelihood.shape, evidence.shape
# Out:
# ((2,), (4548,), (4548, 2))

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(
        np.multiply(this_counts.reshape(-1, 1), evidence), likelihood.reshape(-1, 1))) + 0.001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.7958333333333333

# %% [markdown]
# ### Visualizing a few examples

# %%
def explain(example):
    from IPython.display import HTML
    title, desc, answer = example["title"], example["summary"], example["tag"]
    html = ""
    title = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', title)))
    desc = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', desc)))
    for text in [title, desc]:
        for word in text.split():
            idx = words_to_index[word.lower()]
            if idx == -1:
                html += f"<span style=''>{word}</span> "
            else:
                posterior = np.multiply(evidence[idx], prior)
                posterior /= np.sum(posterior)
                if posterior[0] > posterior[1] if answer == 'cs' else (posterior[0] <= posterior[1]):
                    color = max(0.3, posterior[0] - posterior[1])
                    html += f"<span style='background-color:rgba(0, 255, 0, {color});'>{word}</span> "
                else:
                    color = max(0.3, posterior[1] - posterior[0])
                    html += f"<span style='background-color:rgba(255, 0, 0, {color});'>{word}</span> "
        html += "<br/><br/>"
    return HTML(html)

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style=''>Towards</span> <span style=''>Deep</span> <span style=''>Neural</span> <span style=''>Network</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Architectures</span> <span style=''>Robust</span> <span style=''>to</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Adversarial</span> <span style=''>Examples</span> <br/><br/><span style=''>Recent</span> <span style=''>work</span> <span style=''>has</span> <span style=''>shown</span> <span style=''>deep</span> <span style=''>neural</span> <span style=''>networks</span> <span style=''>(DNNs)</span> <span style=''>to</span> <span style=''>be</span> <span style=''>highly</span> <span style='background-color:rgba(0, 255, 0, 0.4285714285714286);'>susceptible</span> <span style=''>to</span> <span style=''>well</span> <span style=''>designed</span> <span style=''>small</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>perturbations</span> <span style=''>at</span> <span style=''>the</span> <span style=''>input</span> <span style=''>layer</span> <span style=''>or</span> <span style=''>so</span> <span style=''>called</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>adversarial</span> <span style=''>examples</span> <span style=''>Taking</span> <span style=''>images</span> <span style=''>as</span> <span style=''>an</span> <span style=''>example</span> <span style=''>such</span> <span style='background-color:rgba(0, 255, 0, 0.8888888888888888);'>distortions</span> <span style=''>are</span> <span style=''>often</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>imperceptible</span> <span style=''>but</span> <span style=''>can</span> <span style=''>result</span> <span style=''>in</span> <span style=''>100</span> <span style=''>mis</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>classification</span> <span style=''>for</span> <span style=''>a</span> <span style=''>state</span> <span style=''>of</span> <span style=''>the</span> <span style=''>art</span> <span style=''>DNN</span> <span style=''>We</span> <span style=''>study</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>structure</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>adversarial</span> <span style=''>examples</span> <span style=''>and</span> <span style=''>explore</span> <span style=''>network</span> <span style=''>topology</span> <span style=''>pre</span> <span style='background-color:rgba(0, 255, 0, 0.45137157107231923);'>processing</span> <span style=''>and</span> <span style=''>training</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>strategies</span> <span style=''>to</span> <span style=''>improve</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>robustness</span> <span style=''>of</span> <span style=''>DNNs</span> <span style=''>We</span> <span style=''>perform</span> <span style=''>various</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>experiments</span> <span style=''>to</span> <span style=''>assess</span> <span style=''>the</span> <span style=''>removability</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>adversarial</span> <span style=''>examples</span> <span style=''>by</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>corrupting</span> <span style=''>with</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>additional</span> <span style=''>noise</span> <span style=''>and</span> <span style=''>pre</span> <span style='background-color:rgba(0, 255, 0, 0.45137157107231923);'>processing</span> <span style=''>with</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>denoising</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>autoencoders</span> <span style=''>(DAEs)</span> <span style=''>We</span> <span style=''>find</span> <span style=''>that</span> <span style=''>DAEs</span> <span style=''>can</span> <span style=''>remove</span> <span style='background ...

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style=''>When</span> <span style=''>are</span> <span style=''>Kalman</span> <span style=''>filter</span> <span style=''>restless</span> <span style=''>bandits</span> <span style=''>indexable</span> <br/><br/><span style=''>We</span> <span style=''>study</span> <span style=''>the</span> <span style=''>restless</span> <span style=''>bandit</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>associated</span> <span style=''>with</span> <span style=''>an</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>extremely</span> <span style=''>simple</span> <span style=''>scalar</span> <span style=''>Kalman</span> <span style=''>filter</span> <span style=''>model</span> <span style=''>in</span> <span style=''>discrete</span> <span style=''>time</span> <span style=''>Under</span> <span style=''>certain</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>assumptions</span> <span style=''>we</span> <span style=''>prove</span> <span style=''>that</span> <span style=''>the</span> <span style=''>problem</span> <span style=''>is</span> <span style=''>indexable</span> <span style=''>in</span> <span style=''>the</span> <span style=''>sense</span> <span style=''>that</span> <span style=''>the</span> <span style=''>Whittle</span> <span style=''>index</span> <span style=''>is</span> <span style=''>a</span> <span style=''>non</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>decreasing</span> <span style=''>function</span> <span style=''>of</span> <span style=''>the</span> <span style=''>relevant</span> <span style=''>belief</span> <span style=''>state</span> <span style=''>In</span> <span style=''>spite</span> <span style=''>of</span> <span style=''>the</span> <span style=''>long</span> <span style=''>history</span> <span style=''>of</span> <span style=''>this</span> <span style=''>problem</span> <span style=''>this</span> <span style=''>appears</span> <span style=''>to</span> <span style=''>be</span> <span style=''>the</span> <span style=''>first</span> <span style=''>such</span> <span style=''>proof</span> <span style=''>We</span> <span style=''>use</span> <span style=''>results</span> <span style=''>about</span> <span style=''>Schur</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>convexity</span> <span style=''>and</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>mechanical</span> <span style=''>words</span> <span style=''>which</span> <span style=''>are</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>particular</span> <span style=''>binary</span> <span style=''>strings</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>intimately</span> <span style=''>related</span> <span style=''>to</span> <span style=''>palindromes</span> <br/><br/>

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style=''>AdaBatch</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Efficient</span> <span style=''>Gradient</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Aggregation</span> <span style=''>Rules</span> <span style=''>for</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Sequential</span> <span style=''>and</span> <span style=''>Parallel</span> <span style='background-color:rgba(255, 0, 0, 0.323671497584541);'>Stochastic</span> <span style=''>Gradient</span> <span style=''>Methods</span> <br/><br/><span style=''>We</span> <span style=''>study</span> <span style=''>a</span> <span style=''>new</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>aggregation</span> <span style=''>operator</span> <span style=''>for</span> <span style='background-color:rgba(255, 0, 0, 0.3181818181818182);'>gradients</span> <span style=''>coming</span> <span style=''>from</span> <span style=''>a</span> <span style=''>mini</span> <span style=''>batch</span> <span style=''>for</span> <span style='background-color:rgba(255, 0, 0, 0.323671497584541);'>stochastic</span> <span style=''>gradient</span> <span style=''>(SG)</span> <span style=''>methods</span> <span style=''>that</span> <span style=''>allows</span> <span style=''>a</span> <span style='background-color:rgba(0, 255, 0, 0.37336814621409925);'>significant</span> <span style=''>speed</span> <span style=''>up</span> <span style=''>in</span> <span style=''>the</span> <span style=''>case</span> <span style=''>of</span> <span style=''>sparse</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>optimization</span> <span style=''>problems</span> <span style=''>We</span> <span style=''>call</span> <span style=''>this</span> <span style=''>method</span> <span style=''>AdaBatch</span> <span style=''>and</span> <span style=''>it</span> <span style=''>only</span> <span style=''>requires</span> <span style=''>a</span> <span style=''>few</span> <span style=''>lines</span> <span style=''>of</span> <span style=''>code</span> <span style=''>change</span> <span style=''>compared</span> <span style=''>to</span> <span style=''>regular</span> <span style=''>mini</span> <span style=''>batch</span> <span style=''>SGD</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>algorithms</span> <span style=''>We</span> <span style=''>provide</span> <span style=''>a</span> <span style='background-color:rgba(255, 0, 0, 0.327433628318584);'>theoretical</span> <span style=''>insight</span> <span style=''>to</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>understand</span> <span style=''>how</span> <span style=''>this</span> <span style=''>new</span> <span style=''>class</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>algorithms</span> <span style=''>is</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>performing</span> <span style=''>and</span> <span style=''>show</span> <span style=''>that</span> <span style=''>it</span> <span style=''>is</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>equivalent</span> <span style=''>to</span> <span style=''>an</span> <span style=''>implicit</span> <span style=''>per</span> <span style='background-color:rgba(255, 0, 0, 0.5466666666666666);'>coordinate</span> <span style='background-color:rgba(0, 255, 0, 0.6000000000000001);'>rescaling</span> <span style=''>of</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3181818181818182);'>gradients</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>similarly</span> <span style=''>to</span> <span style=''>what</span> <span style=''>Adagrad</span> <span style=''>methods</span> <span style=''>can</span> <span style=''>do</span> <span style=''>In</span> <span style=''>theory</span> <span style=''>and</span> <span style=''>in</span> <span style=''>practice</span> <span style=''>this</span> <span style=''>new</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>aggregation</span> <span  ...

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style=''>Input</span> <span style=''>Warping</span> <span style=''>for</span> <span style=''>Bayesian</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Optimization</span> <span style=''>of</span> <span style=''>Non</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>stationary</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Functions</span> <br/><br/><span style=''>Bayesian</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>optimization</span> <span style=''>has</span> <span style=''>proven</span> <span style=''>to</span> <span style=''>be</span> <span style=''>a</span> <span style=''>highly</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>effective</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>methodology</span> <span style=''>for</span> <span style=''>the</span> <span style=''>global</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>optimization</span> <span style=''>of</span> <span style=''>unknown</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>expensive</span> <span style=''>and</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>multimodal</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>functions</span> <span style=''>The</span> <span style=''>ability</span> <span style=''>to</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>accurately</span> <span style=''>model</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>distributions</span> <span style=''>over</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>functions</span> <span style=''>is</span> <span style=''>critical</span> <span style=''>to</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>effectiveness</span> <span style=''>of</span> <span style=''>Bayesian</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>optimization</span> <span style=''>Although</span> <span style=''>Gaussian</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>processes</span> <span style=''>provide</span> <span style=''>a</span> <span style=''>flexible</span> <span style=''>prior</span> <span style=''>over</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>functions</span> <span style=''>which</span> <span style=''>can</span> <span style=''>be</span> <span style=''>queried</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>efficiently</span> <span style=''>there</span> <span style=''>are</span> <span style=''>various</span> <span style=''>classes</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>functions</span> <span style=''>that</span> <span style=''>remain</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>difficult</span> <span style=''>to</span> <span style=''>model</span> <span style=''>One</span> <span style=''>of</span> <span style=''>the</span> <span style=''>most</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>frequently</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>occurring</span> <span style=''>of</span> <span style=''>these</span> <span style=''>is</span> <span style=''>the</span> <span style=''>class</span> <span style=''>of</span> <span style=''>non</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>stationary</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>functions</span> <span style=''>The</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>optimization</span> <span style=''>of</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>hyperparameters</span> <span style=''>of</span> <span style=''>machine</span> <span style=''>learning</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>algorithms</span> <span style=''>is</span> <span style=''>a</span> <span style=''>problem</span> <span style=''>domain</span> <span style=''>in</span> <span style=''>which</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>parameters</span> <spa ...

# %% [markdown]
# ### Visualizing the Learnt Words

# %%
print("Some Computer Science words are:")
for word_cs in np.argsort(evidence[:, 0] - evidence[:, 1])[-10:]:
    print(f"\t{words[word_cs]} ({evidence[word_cs, 0]})")
print()
print("Some Statistics words are:")
for word_st in np.argsort(evidence[:, 1] - evidence[:, 0])[-10:]:
    print(f"\t{words[word_st]} ({evidence[word_st, 1]})")
# Out:
# Some Computer Science words are:
# 	architecture (0.08380681818181818)
# 	challenging (0.10262784090909091)
# 	information (0.23508522727272727)
# 	processing (0.10333806818181818)
# 	experimental (0.13032670454545456)
# 	segmentation (0.07208806818181818)
# 	different (0.2627840909090909)
# 	detection (0.1299715909090909)
# 	convolutional (0.13245738636363635)
# 	recognition (0.12926136363636365)
#
# Some Statistics words are:
# 	variational (0.10685483870967742)
# 	theoretical (0.15120967741935484)
# 	variables (0.14012096774193547)
# 	statistical (0.1617943548387097)
# 	distribution (0.18699596774193547)
# 	estimation (0.17993951612903225)
# 	inference (0.19959677419354838)
# 	dimensional (0.18800403225806453)
# 	algorithm (0.4022177419354839)
# 	regression (0.19102822580645162)

# %% [markdown]
# ## Probability Smoothing
#
# Probability smoothing is a language modeling technique that assigns some non-zero probability to events that were unseen in the training data. This has the effect that the probability mass is divided over more events, hence the probability distribution becomes more smooth.

# %% [markdown]
# ### Realizing the Problem

# %%
posterior = np.multiply(np.divide(evidence, np.reshape(likelihood, (-1, 1))), np.reshape(prior, (1, -1)))

fig = pg.Figure([pg.Bar(x=words, y=evidence[:20, 0]),
                 pg.Bar(x=words, y=posterior[:20, 0])])
fig.update_layout(title_text='Evidence and Posterior for each word')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="2f96a0bb-4237-4d2a-86d5-043fd0408a48" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("2f96a0bb-4237-4d2a-86d5-043fd0408a48")) {                    Plotly.newPlot(                        "2f96a0bb-4237-4d2a-86d5-043fd0408a48",                        [{"x":["dimensional","experiments","demonstrate","estimation","therefore","numerical","specifically","regularization","parameters","regression","coordinate","penalties","substantial","screening","procedures","efficient","simulated","generalized","formulate","furthermore","regularized","algorithms","unbalanced","algorithm","likelihood","penalized","optimization","advantages","available","desirable","representation","meaningful","depending","smoothness","processing","minimizing","observations","laplacian","synthetic","structured","efficiently","probabilistic","laplacians","framework","application","construction","equivalent","particular","regularity","variations","topologies","applications","variables","representations","especially","resulting","selection","certifiable","recognition","significantly","practical","improving","systematic","improvements","influence","customized","consistently","optimized","variation","analytical","inferences","stationarity","inference","segmentation","convergence","decomposes","approaches","violating","magnitude","structure","difficult","formulation","contribution","structural","rescaling","conditions","dependent","parameter","important","complicated","hierarchical","estimated","approximation","stability","classical","perturbations","minimization","considered","probability","corresponding","hyperparameters","simultaneous","statistics","iterative","lipschitz","empirical","reproducing","extracted","necessary","classification","knowledge","automatically","comparable","conditional","perception","perceptron","techniques","production","architectures","extraction","estimating","performance","different","conventional","extracting","probabilities","motivated","multilayer","separating","convolutional","automatic","indicates","estimates","investigates","comprehensive","satisfies","clarifies","correctly","hopefully","precision","principles","presented","propositional","monotonic","quantified","reasoning","situations","plausible","traditional","evaluating","differences","optimizer","continuous","inspecting","interpreting","inherently","legislative","improvement","political","approximate","correlated","prediction","exploratory","providing","variational","posterior","including","implemented","characteristics","exhibiting","extensions","sensitivity","asymmetric","compression","represents","reproduce","implementation","neuromorphic","frequency","electronic","filtering","implementations","described","implement","nonlinear","discrimination","separates","transmitted","remarkable","decomposition","polygonal","triggered","likelihoods","perturbative","statistical","covariances","importance","gradients","enumerated","perturbation","processes","autoencoders","determines","exploration","estimators","tightness","divergence","divergences","reparameterization","converges","construct","irregular","associated","progressive","assessments","alzheimers","trajectories","variability","modalities","histories","comparisons","complexity","predictions","historical","predicting","interrogated","additional","scenarios","generative","longitudinal","population","benchmarks","progression","trajectory","diagnosis","currently","dictionary","targeting","lemmatization","annotated","distributed","comparison","computation","platforms","validated","theoretical","biological","achieving","activities","cognitive","limitations","potentials","constrained","promising","developed","seamlessly","extension" ...

# %%
print("Some words which never appear in Computer Science paper:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_cs) == 0)[0][:20]]))
print("Some words which never appear in Statistics papers:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_stat) == 0)[0][:20]]))
# Out:
# Some words which never appear in Computer Science paper:
# 	certifiable
# 	unplanned
# 	procrustes
# 	precludes
# 	conveniently
# 	identifiability
# 	regulatory
# 	acceptancerejection
# 	exclusion
# 	integrative
# 	advocated
# 	quantiles
# 	electroencephalography
# 	physician
# 	coregionalization
# 	bivariate
# 	invertibility
# 	checkable
# 	nonparanormal
# 	diffeomorphisms
# Some words which never appear in Statistics papers:
# 	hopefully
# 	propositional
# 	transmitted
# 	polygonal
# 	progressive
# 	interrogated
# 	lemmatization
# 	locomotive
# 	elevation
# 	fascinating
# 	consulting
# 	avoidance
# 	thumbnail
# 	earthquake
# 	disasters
# 	preparedness
# 	unannotated
# 	machinery
# 	polytrees
# 	quantizer

# %% [markdown]
# Notice the fact that there are cases where the Evidence $P\big(\frac{\text{word}}{\text{subject}}\big) \rightarrow 0$. This is because there are occurances of the given word in the corpus (all the abstract of papers put together) of that subject.
#
# However, this is no way implies that if a word (eg. Employment) never occurs in our training corpus in a Computer Science paper, it will also never occur in a paper in the test set.
#
# Therefore, setting $P(\text{word} | \text{subject}) = 0$ is incorrect, since it will make the posterior $P(\text{subject} | \text{word}) = 0$, even if the corresponding count it 0, we need to come up with a smoother formulation of the Evidence variables.

# %% [markdown]
# ### Laplace Smoothing
#
#
#
# https://towardsdatascience.com/laplace-smoothing-in-na%C3%AFve-bayes-algorithm-9c237a8bdece

# %%
alpha = 0.1
counts_cs, counts_stat = np.array(counts_cs), np.array(counts_stat)
evidence_smooth = np.array([(counts_cs + alpha) / (train_df["tag"].value_counts()["cs"] + alpha * len(words)),
                            (counts_stat + alpha) / (train_df["tag"].value_counts()["stat"] + alpha * len(words))]).T
print(np.min(evidence_smooth))
sns.displot(evidence_smooth)
# Out:
# 3.057355998532469e-05

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(np.multiply(this_counts.reshape(-1, 1), evidence_smooth), likelihood.reshape(-1, 1))) + 0.0000001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.7583333333333333
